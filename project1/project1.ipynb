# %%
from sklearn.datasets import fetch_california_housing

# %%
dataset = fetch_california_housing()
x_full= dataset.data
y_full= dataset.target

# %%
x_full.shape
# Out:
# (20640, 8)

# %%
y_full.shape
# Out:
# (20640,)

# %%
y_full
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np

# %%
plt.figure(figsize=(10,10))
plt.scatter(x_full[:,4],x_full[:,1],c=y_full)

# %%
x_full.mean(axis=0)
# Out:
# array([ 3.87067100e+00,  2.86394864e+01,  5.42899974e+00,  1.09667515e+00,
#         1.42547674e+03,  3.07065516e+00,  3.56318614e+01, -1.19569704e+02])

# %%
x_full.var(axis=0)
# Out:
# array([3.60914769e+00, 1.58388586e+02, 6.12123614e+00, 2.24580619e-01,
#        1.28240832e+06, 1.07864799e+02, 4.56207160e+00, 4.01394488e+00])

# %%
from sklearn.preprocessing import StandardScaler

# %%
stcaler = StandardScaler().fit(x_full)

# %%
x_all_stcaler=stcaler.transform(x_full)

# %%
x_all_stcaler.mean(axis=0)
# Out:
# array([ 6.60969987e-17,  5.50808322e-18,  6.60969987e-17, -1.06030602e-16,
#        -1.10161664e-17,  3.44255201e-18, -1.07958431e-15, -8.52651283e-15])

# %%
x_all_stcaler.var(axis=0)
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1.])

# %%
plt.figure(figsize=(10,10))
plt.scatter(x_all_stcaler[:,4],x_all_stcaler[:,1],c=y_full)

# %%
plt.hist(x_full[:,0],bins=100)
plt.figure()
plt.hist(x_all_stcaler[:,0],bins=100)
# Out:
# (array([ 24.,  26.,  66.,  97., 152., 195., 289., 386., 514., 498., 589.,
#         752., 699., 664., 866., 726., 681., 843., 914., 702., 687., 826.,
#         673., 586., 712., 689., 516., 474., 504., 431., 344., 468., 391.,
#         324., 305., 277., 217., 181., 275., 208., 161., 149., 145., 135.,
#          93.,  75.,  88.,  59.,  84.,  71.,  74.,  63.,  61.,  48.,  48.,
#          38.,  31.,  29.,  17.,  19.,  16.,  12.,  14.,   9.,  21.,  12.,
#          32.,  26.,  22.,  14.,  21.,  14.,  16.,  11.,   7.,   3.,   6.,
#           8.,   2.,   5.,   5.,   7.,   4.,   6.,   2.,   5.,   4.,   4.,
#           6.,   4.,   3.,   1.,   2.,   0.,   0.,   3.,   1.,   1.,   0.,
#          52.]),
#  array([-1.77429947, -1.69797361, -1.62164776, -1.54532191, -1.46899606,
#         -1.3926702 , -1.31634435, -1.2400185 , -1.16369264, -1.08736679,
#         -1.01104094, -0.93471509, -0.85838923, -0.78206338, -0.70573753,
# ...

# %%
plt.hist(x_full[:,1],bins=100)
plt.figure()
plt.hist(x_all_stcaler[:,1],bins=100)
# Out:
# (array([   4.,   58.,    0.,   62.,    0.,  191.,    0.,  244.,    0.,
#          160.,    0.,  175.,    0.,  206.,    0.,  205.,    0.,  264.,
#            0.,  254.,    0.,  238.,    0.,  302.,    0.,  412.,    0.,
#          512.,    0.,  771.,    0.,  698.,    0.,  570.,    0.,  502.,
#            0.,  465.,    0.,  446.,    0.,  399.,    0.,  448.,    0.,
#          478.,    0.,  566.,    0.,  619.,  488.,    0.,  471.,    0.,
#          461.,    0.,  476.,    0.,  458.,    0.,  565.,    0.,  615.,
#            0.,  689.,    0.,  824.,    0.,  862.,    0.,  537.,    0.,
#          394.,    0.,  369.,    0.,  304.,    0.,  296.,    0.,  368.,
#            0.,  353.,    0.,  356.,    0.,  294.,    0.,  245.,    0.,
#          198.,    0.,  177.,    0.,  134.,    0.,  136.,    0.,   48.,
#         1273.]),
#  array([-2.19618048, -2.15565686, -2.11513324, -2.07460962, -2.034086  ,
#         -1.99356238, -1.95303876, -1.91251514, -1.87199152, -1.8314679 ,
# ...

# %%
plt.hist(x_full[:,4],bins=100)
plt.figure()
plt.hist(x_all_stcaler[:,4],bins=100)
# Out:
# (array([1.087e+03, 3.112e+03, 4.947e+03, 4.027e+03, 2.683e+03, 1.657e+03,
#         9.350e+02, 6.490e+02, 4.380e+02, 2.810e+02, 2.100e+02, 1.200e+02,
#         9.900e+01, 9.000e+01, 4.900e+01, 4.200e+01, 2.700e+01, 2.900e+01,
#         2.400e+01, 2.100e+01, 3.200e+01, 1.800e+01, 7.000e+00, 6.000e+00,
#         1.100e+01, 3.000e+00, 5.000e+00, 8.000e+00, 2.000e+00, 3.000e+00,
#         2.000e+00, 2.000e+00, 0.000e+00, 3.000e+00, 3.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmaxsc = MinMaxScaler(feature_range=(-3,5)).fit(x_full)

# %%
x_all_minmaxsc = minmaxsc.transform(x_full)

# %%
x_all_minmaxsc.mean(axis=0)
# Out:
# array([-1.14028993,  1.33560572, -2.74009639, -2.81897032, -2.68105009,
#        -2.98468843, -0.37142492,  0.80900043])

# %%
x_all_minmaxsc.var(axis=0)
# Out:
# array([1.09859253, 3.89729701, 0.01968762, 0.01263088, 0.06447346,
#        0.00447063, 3.29733312, 2.54849598])

# %%
x_all_minmaxsc.min(axis=0)
# Out:
# array([-3., -3., -3., -3., -3., -3., -3., -3.])

# %%
x_all_minmaxsc.max(axis=0)
# Out:
# array([5., 5., 5., 5., 5., 5., 5., 5.])

# %%
plt.figure(figsize=(10,10))
plt.scatter(x_all_minmaxsc[:,0],x_all_minmaxsc[:,1],c=y_full)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x_all_minmaxsc[:,4],x_all_minmaxsc[:,1],c=y_full)

# %%
plt.hist(x_full[:,0],bins=100)
plt.figure()
plt.hist(x_all_minmaxsc[:,0],bins=100)
# Out:
# (array([ 24.,  26.,  66.,  97., 152., 195., 289., 386., 514., 498., 589.,
#         752., 699., 664., 866., 726., 681., 843., 914., 702., 687., 826.,
#         673., 586., 712., 689., 516., 474., 504., 431., 344., 468., 391.,
#         324., 305., 277., 217., 181., 275., 208., 161., 149., 145., 135.,
#          93.,  75.,  88.,  59.,  84.,  71.,  74.,  63.,  61.,  48.,  48.,
#          38.,  31.,  29.,  17.,  19.,  16.,  12.,  14.,   9.,  21.,  12.,
#          32.,  26.,  22.,  14.,  21.,  14.,  16.,  11.,   7.,   3.,   6.,
#           8.,   2.,   5.,   5.,   7.,   4.,   6.,   2.,   5.,   4.,   4.,
#           6.,   4.,   3.,   1.,   2.,   0.,   0.,   3.,   1.,   1.,   0.,
#          52.]),
#  array([-3.  , -2.92, -2.84, -2.76, -2.68, -2.6 , -2.52, -2.44, -2.36,
#         -2.28, -2.2 , -2.12, -2.04, -1.96, -1.88, -1.8 , -1.72, -1.64,
#         -1.56, -1.48, -1.4 , -1.32, -1.24, -1.16, -1.08, -1.  , -0.92,
#         -0.84, -0.76, -0.68, -0.6 , -0.52, -0.44, -0.36, -0.28, -0.2 ,
# ...

# %%
plt.hist(x_full[:,1],bins=100)
plt.figure()
plt.hist(x_all_minmaxsc[:,1],bins=100)
# Out:
# (array([   4.,   58.,    0.,   62.,    0.,  191.,    0.,  244.,    0.,
#          160.,    0.,  175.,    0.,  206.,    0.,  205.,    0.,  264.,
#            0.,  254.,    0.,  238.,    0.,  302.,    0.,  412.,    0.,
#          512.,    0.,  771.,    0.,  698.,    0.,  570.,    0.,  502.,
#            0.,  465.,    0.,  446.,    0.,  399.,    0.,  448.,    0.,
#          478.,    0.,  566.,    0.,  619.,  488.,    0.,  471.,    0.,
#          461.,    0.,  476.,    0.,  458.,    0.,  565.,    0.,  615.,
#            0.,  689.,    0.,  824.,    0.,  862.,    0.,  537.,    0.,
#          394.,    0.,  369.,    0.,  304.,    0.,  296.,    0.,  368.,
#            0.,  353.,    0.,  356.,    0.,  294.,    0.,  245.,    0.,
#          198.,    0.,  177.,    0.,  134.,    0.,  136.,    0.,   48.,
#         1273.]),
#  array([-3.  , -2.92, -2.84, -2.76, -2.68, -2.6 , -2.52, -2.44, -2.36,
#         -2.28, -2.2 , -2.12, -2.04, -1.96, -1.88, -1.8 , -1.72, -1.64,
# ...

# %%
plt.hist(x_full[:,4],bins=100)
plt.figure()
plt.hist(x_all_minmaxsc[:,4],bins=100)
# Out:
# (array([1.087e+03, 3.112e+03, 4.947e+03, 4.027e+03, 2.683e+03, 1.657e+03,
#         9.350e+02, 6.490e+02, 4.380e+02, 2.810e+02, 2.100e+02, 1.200e+02,
#         9.900e+01, 9.000e+01, 4.900e+01, 4.200e+01, 2.700e+01, 2.900e+01,
#         2.400e+01, 2.100e+01, 3.200e+01, 1.800e+01, 7.000e+00, 6.000e+00,
#         1.100e+01, 3.000e+00, 5.000e+00, 8.000e+00, 2.000e+00, 3.000e+00,
#         2.000e+00, 2.000e+00, 0.000e+00, 3.000e+00, 3.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
maxabssc = MaxAbsScaler().fit(x_full)

# %%
x_all_maxabssc = maxabssc.transform(x_full)

# %%
x_all_maxabssc.mean(axis=0)
# Out:
# array([ 0.25804301,  0.55075935,  0.03825688,  0.03219203,  0.03994946,
#         0.0024697 ,  0.84938883, -0.96155774])

# %%
x_all_maxabssc.max(axis=0)
# Out:
# array([ 1.        ,  1.        ,  1.        ,  1.        ,  1.        ,
#         1.        ,  1.        , -0.91926015])

# %%
x_all_maxabssc.min(axis=0)
# Out:
# array([ 3.33264445e-02,  1.92307692e-02,  5.96264722e-03,  9.78473581e-03,
#         8.40760047e-05,  5.56815838e-04,  7.75685340e-01, -1.00000000e+00])

# %%
plt.hist(x_full[:,0],bins=100)
plt.figure()
plt.hist(x_all_maxabssc[:,0],bins=100)
# Out:
# (array([ 24.,  26.,  66.,  97., 152., 195., 289., 386., 514., 498., 589.,
#         752., 699., 664., 866., 726., 681., 843., 914., 702., 687., 826.,
#         673., 586., 712., 689., 516., 474., 504., 431., 344., 468., 391.,
#         324., 305., 277., 217., 181., 275., 208., 161., 149., 145., 135.,
#          93.,  75.,  88.,  59.,  84.,  71.,  74.,  63.,  61.,  48.,  48.,
#          38.,  31.,  29.,  17.,  19.,  16.,  12.,  14.,   9.,  21.,  12.,
#          32.,  26.,  22.,  14.,  21.,  14.,  16.,  11.,   7.,   3.,   6.,
#           8.,   2.,   5.,   5.,   7.,   4.,   6.,   2.,   5.,   4.,   4.,
#           6.,   4.,   3.,   1.,   2.,   0.,   0.,   3.,   1.,   1.,   0.,
#          52.]),
#  array([0.03332644, 0.04299318, 0.05265992, 0.06232665, 0.07199339,
#         0.08166012, 0.09132686, 0.10099359, 0.11066033, 0.12032706,
#         0.1299938 , 0.13966054, 0.14932727, 0.15899401, 0.16866074,
#         0.17832748, 0.18799421, 0.19766095, 0.20732768, 0.21699442,
# ...

# %%
plt.hist(x_full[:,1],bins=100)
plt.figure()
plt.hist(x_all_maxabssc[:,1],bins=100)
# Out:
# (array([   4.,   58.,    0.,   62.,    0.,  191.,    0.,  244.,    0.,
#          160.,    0.,  175.,    0.,  206.,    0.,  205.,    0.,  264.,
#            0.,  254.,    0.,  238.,    0.,  302.,    0.,  412.,    0.,
#          512.,    0.,  771.,    0.,  698.,    0.,  570.,    0.,  502.,
#            0.,  465.,    0.,  446.,    0.,  399.,    0.,  448.,    0.,
#          478.,    0.,  566.,    0.,  619.,  488.,    0.,  471.,    0.,
#          461.,    0.,  476.,    0.,  458.,    0.,  565.,    0.,  615.,
#            0.,  689.,    0.,  824.,    0.,  862.,    0.,  537.,    0.,
#          394.,    0.,  369.,    0.,  304.,    0.,  296.,    0.,  368.,
#            0.,  353.,    0.,  356.,    0.,  294.,    0.,  245.,    0.,
#          198.,    0.,  177.,    0.,  134.,    0.,  136.,    0.,   48.,
#         1273.]),
#  array([0.01923077, 0.02903846, 0.03884615, 0.04865385, 0.05846154,
#         0.06826923, 0.07807692, 0.08788462, 0.09769231, 0.1075    ,
# ...

# %%
plt.hist(x_full[:,4],bins=100)
plt.figure()
plt.hist(x_all_maxabssc[:,4],bins=100)
# Out:
# (array([1.087e+03, 3.112e+03, 4.947e+03, 4.027e+03, 2.683e+03, 1.657e+03,
#         9.350e+02, 6.490e+02, 4.380e+02, 2.810e+02, 2.100e+02, 1.200e+02,
#         9.900e+01, 9.000e+01, 4.900e+01, 4.200e+01, 2.700e+01, 2.900e+01,
#         2.400e+01, 2.100e+01, 3.200e+01, 1.800e+01, 7.000e+00, 6.000e+00,
#         1.100e+01, 3.000e+00, 5.000e+00, 8.000e+00, 2.000e+00, 3.000e+00,
#         2.000e+00, 2.000e+00, 0.000e+00, 3.000e+00, 3.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
plt.figure(figsize=(10,10))
plt.scatter(x_all_maxabssc[:,0],x_all_maxabssc[:,1],c=y_full)

# %%
from sklearn.preprocessing import RobustScaler

# %%
rbscaler = RobustScaler(quantile_range=(30,80)).fit(x_full)
x_all_rbscaler=rbscaler.transform(x_full)

# %%
x_all_rbscaler.mean(axis=0)
# Out:
# array([ 0.14174045, -0.01802568,  0.12063888,  0.47687298,  0.24735629,
#         0.27674672,  0.36006862, -0.3102599 ])

# %%
x_all_rbscaler.var(axis=0)
# Out:
# array([  0.64275763,   0.39597147,   2.23004872,  22.26401461,
#          1.16540091, 129.5346747 ,   0.31427667,   0.3314461 ])

# %%
x_all_rbscaler.min(axis=0)
# Out:
# array([-1.28075388, -1.4       , -2.64549288, -7.12349564, -1.10867493,
#        -2.32957759, -0.45144357, -1.68390805])

# %%
x_all_rbscaler.max(axis=0)
# Out:
# array([4.83845511e+00, 1.15000000e+00, 8.24978174e+01, 3.28749324e+02,
#        3.29037178e+01, 1.35942498e+03, 2.01837270e+00, 1.20114943e+00])

# %%
plt.figure(figsize=(10,10))
plt.scatter(x_all_rbscaler[:,0],x_all_rbscaler[:,1],c=y_full)

# %%
plt.figure(figsize=(10,10))
plt.scatter(x_all_rbscaler[:,4],x_all_rbscaler[:,0],c=y_full)
