# %% [markdown]
# # Linear Regression
#
# In Machine Learning lingo, Linear Regression (LR) means simply finding the best fitting line that explains the variability between the dependent and independent features very well or we can say it describes the linear relationship between independent and dependent features, and in linear regression, the algorithm predicts the continuous features(e.g. Salary, Price ), rather than deal with the categorical features (e.g. cat, dog).

# %% [markdown]
# ### 1. Simple Linear Regression
#
# In simple linear regression, there is only one predictor variable. Since our goal is to predict the crew variable, we see from Figure 1 that the cabins variable correlates the most with the crew variable. Hence our simple regression model can be expressed in the form:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

plt.figure(figsize=(8, 6), dpi=80)
image = img.imread('1.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# where m is the slope or regression coefficient, and c is the intercept

# %%
plt.figure(figsize=(10, 8), dpi=80)
image = img.imread('2.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# ### 2. Multiple Linear Regression
#
#
# Suppose that the target variable now depends on several predictor variables (for e.g. four predictor variables), then the system can be modeled using multiple regression analysis:

# %%
plt.figure(figsize=(8, 6), dpi=80)
image = img.imread('3.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# where X is the features matrix, w_0 is the intercept, and w_1, w_2, w_3, and w_4 are the regression coefficients.

# %% [markdown]
# ## Evaluating Linear Regression Models
#
#
# The most popular metric used for evaluating the performance of linear regression models is the R2 score metric which can be calculated as follows:

# %%
plt.figure(figsize=(8, 6), dpi=80)
image = img.imread('4.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# The R2 score takes values between 0 and 1. When R2 is close to 1, it means the predicted values agree closely with the actual values. If R2 is close to zero, then it means the predictive power of the model is very poor.
#
# Other metrics that could also be used for evaluating a linear regression model include the following:
#
# - MSE (Mean Square Error): Uses Euclidean distance to calculate the error. MSE gives the magnitude of the error only.

# %%
plt.figure(figsize=(8, 6), dpi=80)
image = img.imread('5.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# - MAE (Mean Absolute Error): Uses Manhattan distance to calculate the error. MAE (like MSE) gives the magnitude of the error only.

# %%
plt.figure(figsize=(6, 4), dpi=80)
image = img.imread('6.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# - ME (Mean Error): Keeps track of the sign of error, is model over-predicting (ME > 0) or under-predicting (ME < 0)?

# %%
plt.figure(figsize=( 6,4), dpi=80)
image = img.imread('7.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# - R2 Score is a very popular metric used for __evaluating the performance of linear regression models__
# - Use MSE or MAE __when comparing two or more models, the lower the value of MSE or MAE, the better__
# - Use ME when you are __interested in understanding if on average, your model is over-predicting (ME > 0) or under-predicting (ME < 0)__. One could also use the R2 Score to compare different models.

# %% [markdown]
# # Implementation

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# creating a dummy dataset
np.random.seed(10)
x = np.random.rand(50, 1)
y = 3 + 3 * x + np.random.rand(50, 1)

#scatterplot

plt.scatter(x,y,s=10)
plt.xlabel('x_dummy')
plt.ylabel('y_dummy')
plt.show()

#creating a model
from sklearn.linear_model import LinearRegression

# creating a object
regressor = LinearRegression()

#training the model
regressor.fit(x, y)

#using the training dataset for the prediction
pred = regressor.predict(x)

#model performance
from sklearn.metrics import r2_score, mean_squared_error
mse = mean_squared_error(y, pred)
r2 = r2_score(y, pred)#Best fit lineplt.scatter(x, y)
plt.plot(x, pred, color = 'Black', marker = 'o')

#Results
print("Mean Squared Error : ", mse)
print("R-Squared :" , r2)
print("Y-intercept :"  , regressor.intercept_)
print("Slope :" , regressor.coef_)

# R-Squared : 0.9068822972556425
# Y-intercept : [3.41354381]
# Slope : [[3.11024701]]
# Out:
# Mean Squared Error :  0.0746314112910216
# R-Squared : 0.9068822972556425
# Y-intercept : [3.41354381]
# Slope : [[3.11024701]]

# %% [markdown]
# ### Sources :
# - https://www.kdnuggets.com/2022/07/linear-regression-data-science.html
# - https://www.analyticsvidhya.com/blog/2022/02/linear-regression-with-python-implementation/
