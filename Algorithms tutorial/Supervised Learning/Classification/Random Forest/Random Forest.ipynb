# %% [markdown]
# # Random Forest

# %% [markdown]
# Random forest is a classifier algorithem which uses decision tree concept to get data classified.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

plt.figure(figsize=(12, 10), dpi=80)
image = img.imread('1.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# #### Source : https://www.youtube.com/watch?v=3LQI-w7-FuE
