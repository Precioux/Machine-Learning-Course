# %% [markdown]
# # Cross Validation

# %% [markdown]
# - ## The process of using test data to evaluate our model is called cross-validation.
#   - ## Two common methods are:
#     - ## Train_Test Split
#     - ## K-fold Cross Validation

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
plt.figure(figsize=(12, 10), dpi=80)
image = img.imread('tt.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# ### - When working with 100,000+ rows of data we can use a ratio of 90:10 and with 1,000,00+ data rows 99:1
# ### - In general when working with more data, we can use a smaller percentage of test data since we have sufficient training data to build a reasonably accurate model

# %%
plt.figure(figsize=(12, 10), dpi=80)
image = img.imread('tt2.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %%
plt.figure(figsize=(12, 10), dpi=80)
image = img.imread('k.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %%
plt.figure(figsize=(12, 10), dpi=80)
image = img.imread('k2.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %%
plt.figure(figsize=(12, 10), dpi=80)
image = img.imread('k3.png')
plt.axis('off')
plt.imshow(image)
plt.show()

# %% [markdown]
# ### Source : https://linguisticmaz.medium.com/cross-validation-explained-6496e68d62a7
